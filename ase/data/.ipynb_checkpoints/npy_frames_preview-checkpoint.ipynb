# %% [markdown]
# # NPY Frames Preview
#
# Preview a few frames from motion files in `ase/data/motions/pingpong`.
#
# Run the import bootstrap cell first so `poselib` imports correctly in Jupyter.
#
# This notebook shows:
# - file-level metadata
# - selected frame quaternions (`rotation.arr`)
# - selected frame root translation (`root_translation.arr`)

# %%
# Notebook import bootstrap for local repo modules
import sys
from pathlib import Path

# Resolve repo root whether notebook is run from repo root or from ase/data
cwd = Path.cwd().resolve()
if (cwd / "ase").exists():
    repo_root = cwd
elif (cwd.parent / "ase").exists():
    repo_root = cwd.parent
elif (cwd.parent.parent / "ase").exists():
    repo_root = cwd.parent.parent
else:
    raise RuntimeError("Could not locate repo root containing 'ase' directory.")

ase_path = repo_root / "ase"
if str(ase_path) not in sys.path:
    sys.path.insert(0, str(ase_path))

print("repo_root:", repo_root)
print("ase_path added to sys.path:", ase_path)

# Canonical import used in this notebook
from poselib.poselib.skeleton.skeleton3d import SkeletonMotion
print("poselib import OK")
# Out:
# 2026-04-27 11:48:22,566 - INFO - logger - logger initialized
# repo_root: /Users/zainaqasim/Repositories/pingpong
# ase_path added to sys.path: /Users/zainaqasim/Repositories/pingpong/ase
# Error: FBX library failed to load - importing FBX data will not succeed. Message: No module named 'fbx'
# FBX tools must be installed from https://help.autodesk.com/view/FBX/2020/ENU/?guid=FBX_Developer_Help_scripting_with_python_fbx_installing_python_fbx_html
# /Users/zainaqasim/Repositories/pingpong/ase/poselib/poselib/core/rotation3d.py:223: SyntaxWarning: invalid escape sequence '\*'
#   Combine two set of 3D rotations together using \**\* operator. The shape needs to be
# <unknown>:4: SyntaxWarning: invalid escape sequence '\*'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 24
#      20 print("repo_root:", repo_root)
#      21 print("ase_path added to sys.path:", ase_path)
#      22
#      23 # Canonical import used in this notebook
# ---> 24 from poselib.poselib.skeleton.skeleton3d import SkeletonMotion
#      25 print("poselib import OK")
#
# File ~/Repositories/pingpong/ase/poselib/poselib/skeleton/skeleton3d.py:39
#      37 from ..core import *
#      38 from .backend.fbx.fbx_read_wrapper import fbx_to_array
# ---> 39 import scipy.ndimage.filters as filters
#      42 class SkeletonTree(Serializable):
#      43     """
#      44     A skeleton tree gives a complete description of a rigid skeleton. It describes a tree structure
#      45     over a list of nodes with their names indicated by strings. Each edge in the tree has a local
#    (...)     92         'aux_1'
#      93     """
#
# ModuleNotFoundError: No module named 'scipy'

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys

# Paths
MOTION_DIR = repo_root / "ase" / "data" / "motions" / "pingpong"
OUT_DIR = repo_root / "output" / "analysis"
OUT_DIR.mkdir(parents=True, exist_ok=True)

npy_files = sorted(MOTION_DIR.glob("*.npy"))
print(f"Found {len(npy_files)} .npy motion files in {MOTION_DIR}")
npy_files[:5]
# Out:
# Found 30 .npy motion files
# [PosixPath('motions/pingpong/ROM_blender_pph.npy'),
#  PosixPath('motions/pingpong/Transition_looping_FB_blender_pph.npy'),
#  PosixPath('motions/pingpong/backhand_blender_pph.npy'),
#  PosixPath('motions/pingpong/backhand_block_01_blender_pph.npy'),
#  PosixPath('motions/pingpong/backhand_chop001_blender_pph.npy')]

# %%
# Use absolute import after bootstrap cell adjusts sys.path
from poselib.poselib.skeleton.skeleton3d import SkeletonMotion
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ..poselib.poselib.skeleton.skeleton3d import SkeletonMotion
#
# ImportError: attempted relative import with no known parent package

# %%
def load_payload(path: Path):
    arr = np.load(path, allow_pickle=True)
    if not (isinstance(arr, np.ndarray) and arr.dtype == object and arr.size == 1):
        raise ValueError(f"Unexpected npy layout in {path}")
    payload = arr.item()
    if not isinstance(payload, dict):
        raise ValueError(f"Payload is not dict in {path}")
    return payload


def extract_arrays(payload: dict):
    # Expected SkeletonMotion layout
    rot = payload["rotation"]["arr"]               # [F, J, 4]
    root_t = payload["root_translation"]["arr"]    # [F, 3]
    gvel = payload["global_velocity"]["arr"]       # [F, J, 3]
    gavel = payload["global_angular_velocity"]["arr"]  # [F, J, 3]
    fps = float(payload.get("fps", 30.0))
    return rot, root_t, gvel, gavel, fps


def summarize_numeric(arr: np.ndarray):
    flat = arr.astype(np.float64, copy=False).reshape(-1)
    finite = flat[np.isfinite(flat)]
    if finite.size == 0:
        return {
            "min": np.nan, "max": np.nan, "mean": np.nan, "std": np.nan,
            "nan_count": int(np.isnan(flat).sum()),
            "inf_count": int(np.isinf(flat).sum()),
        }
    return {
        "min": float(np.min(finite)),
        "max": float(np.max(finite)),
        "mean": float(np.mean(finite)),
        "std": float(np.std(finite)),
        "nan_count": int(np.isnan(flat).sum()),
        "inf_count": int(np.isinf(flat).sum()),
    }

# %%
# 0) Quick look at raw data structure
test_file_path = sorted(npy_files)[0]
print("Using:", test_file_path)
# Out:
# Using: motions/pingpong/ROM_blender_pph.npy

# %%
payload = np.load(test_file_path, allow_pickle=True).item()

# %%
payload.keys()
# Out:
# odict_keys(['rotation', 'root_translation', 'global_velocity', 'global_angular_velocity', 'skeleton_tree', 'is_local', 'fps', '__name__'])

# %%
# Check if all files have the same keys 
all_keys = set(payload.keys())
for p in npy_files:
    payload = np.load(p, allow_pickle=True).item()
    if set(payload.keys()) != all_keys:
        raise ValueError(f"Keys mismatch in {p}")
print("All files have the same keys")
# Out:
# All files have the same keys

# %%
for key in payload.keys():
    value = payload[key]
    if isinstance(value, dict):
        print(f"Key '{key}': sub-keys = {list(value.keys())}")
    else:
        print(f"Key '{key}': not a dict (type={type(value).__name__})")
# Out:
# Key 'rotation': sub-keys = ['arr', 'context']
# Key 'root_translation': sub-keys = ['arr', 'context']
# Key 'global_velocity': sub-keys = ['arr', 'context']
# Key 'global_angular_velocity': sub-keys = ['arr', 'context']
# Key 'skeleton_tree': sub-keys = ['node_names', 'parent_indices', 'local_translation']
# Key 'is_local': not a dict (type=bool)
# Key 'fps': not a dict (type=float)
# Key '__name__': not a dict (type=str)

# %%
# Inspection of payload structure according to known keys/subkeys

# 'rotation': dict with sub-keys ['arr', 'context']
rotation = payload['rotation']
print("Key 'rotation': sub-keys =", list(rotation.keys()))
print("  First element of 'rotation[\"arr\"]':", rotation['arr'][0])
print("  First element of 'rotation[\"context\"]':", rotation['context'][0] if isinstance(rotation['context'], (list, np.ndarray)) else rotation['context'])
# Out:
# Key 'rotation': sub-keys = ['arr', 'context']
#   First element of 'rotation["arr"]': [[ 0.04549544 -0.05016099  0.08467107  0.99410504]
#  [-0.07364252  0.08473399  0.01712149  0.993531  ]
#  [-0.03021524  0.11153963  0.15848958  0.9805749 ]
#  [-0.23671098 -0.2207794   0.3209661   0.89005905]
#  [-0.         -0.73766583 -0.          0.675166  ]
#  [ 0.          0.          0.          1.        ]
#  [ 0.33243167 -0.18135393 -0.3235287   0.8671385 ]
#  [-0.         -0.7175387  -0.          0.6965187 ]
#  [ 0.04373811  0.16188611 -0.439839    0.882282  ]
#  [-0.1732877  -0.05132364 -0.08760663  0.9796236 ]
#  [ 0.          0.22048643  0.          0.9753901 ]
#  [ 0.16784082 -0.06382147  0.03170565  0.983235  ]
#  [-0.02748942  0.03743633  0.25003275  0.9671228 ]
#  [ 0.          0.06173404  0.          0.99809265]
#  [-0.01617871 -0.04301477  0.12659225  0.9908897 ]]
#   First element of 'rotation["context"]': {'dtype': 'float32'}

# %%
# 'root_translation': dict with sub-keys ['arr', 'context']
root_translation = payload['root_translation']
print("Key 'root_translation': sub-keys =", list(root_translation.keys()))
print("  First element of 'root_translation[\"arr\"]':", root_translation['arr'][0])
print("  First element of 'root_translation[\"context\"]':", root_translation['context'][0] if isinstance(root_translation['context'], (list, np.ndarray)) else root_translation['context'])
# Out:
# Key 'root_translation': sub-keys = ['arr', 'context']
#   First element of 'root_translation["arr"]': [-0.8567481  -0.23037001  0.8874401 ]
#   First element of 'root_translation["context"]': {'dtype': 'float32'}

# %%
# 'global_velocity': dict with sub-keys ['arr', 'context']
global_velocity = payload['global_velocity']
print("Key 'global_velocity': sub-keys =", list(global_velocity.keys()))
print("  First element of 'global_velocity[\"arr\"]':", global_velocity['arr'][0])
print("  First element of 'global_velocity[\"context\"]':", global_velocity['context'][0] if isinstance(global_velocity['context'], (list, np.ndarray)) else global_velocity['context'])
# Out:
# Key 'global_velocity': sub-keys = ['arr', 'context']
#   First element of 'global_velocity["arr"]': [[-0.01465683 -0.14832906 -0.01336988]
#  [ 0.00644655 -0.23564184 -0.02092438]
#  [ 0.00395819 -0.27049676 -0.01850868]
#  [ 0.16605924 -0.24775021 -0.05941894]
#  [ 0.20923248 -0.10026    -0.06542332]
#  [ 0.01249416  0.01239522 -0.08749867]
#  [-0.14823978 -0.32149786  0.02148682]
#  [-0.28313443 -0.22625796  0.02256563]
#  [-0.17517224 -0.04864903 -0.03299262]
#  [ 0.04226409 -0.13500111 -0.02975752]
#  [-0.10701372  0.03672507 -0.10105987]
#  [-0.05349623  0.11212098 -0.12901695]
#  [-0.07157774 -0.16165732  0.00301776]
#  [-0.06928595 -0.05782482  0.00631571]
#  [-0.00428537  0.04533799 -0.00126412]]
#   First element of 'global_velocity["context"]': {'dtype': 'float32'}

# %%
# 'global_angular_velocity': dict with sub-keys ['arr', 'context']
global_angular_velocity = payload['global_angular_velocity']
print("Key 'global_angular_velocity': sub-keys =", list(global_angular_velocity.keys()))
print("  First element of 'global_angular_velocity[\"arr\"]':", global_angular_velocity['arr'][0])
print("  First element of 'global_angular_velocity[\"context\"]':", global_angular_velocity['context'][0] if isinstance(global_angular_velocity['context'], (list, np.ndarray)) else global_angular_velocity['context'])
# Out:
# Key 'global_angular_velocity': sub-keys = ['arr', 'context']
#   First element of 'global_angular_velocity["arr"]': [[ 1.8536367e-01 -1.7582605e-02  7.1365643e-01]
#  [ 2.1415585e-01  5.3810470e-02  8.3991504e-01]
#  [ 6.9969869e-01 -8.3316818e-02  2.7724636e+00]
#  [ 1.0310621e-02  3.9897077e-02  1.0101840e+00]
#  [-3.6946826e-02  7.8928955e-02  9.6687025e-01]
#  [-3.6947709e-02  7.8929044e-02  9.6686059e-01]
#  [ 9.4706282e-02  1.4483619e-01  8.2526511e-01]
#  [ 1.1946101e-01  1.9757462e-01  8.7222475e-01]
#  [ 7.4061191e-01  2.6497918e-01  1.1029907e+00]
#  [ 3.2833564e-01  4.5068607e-01  3.4167227e-01]
#  [ 3.1091774e-01 -4.0166501e-02  4.4892067e-01]
#  [-5.9164196e-01 -5.4665512e-01  1.3793714e-01]
#  [ 2.1150312e-01 -3.1948093e-02  7.5479132e-01]
#  [ 2.8442997e-01 -1.1694921e-01  7.5568640e-01]
#  [ 5.4117327e-04 -6.4734876e-02 -9.2556793e-03]]
#   First element of 'global_angular_velocity["context"]': {'dtype': 'float32'}

# %%
# 'skeleton_tree': dict with sub-keys ['node_names', 'parent_indices', 'local_translation']
skeleton_tree = payload['skeleton_tree']
print("Key 'skeleton_tree': sub-keys =", list(skeleton_tree.keys()))
print("  First element of 'skeleton_tree[\"node_names\"]':", skeleton_tree['node_names'][0])
print("  First element of 'skeleton_tree[\"parent_indices\"]':", skeleton_tree['parent_indices']['arr'])
print("  First element of 'skeleton_tree[\"local_translation\"]':", skeleton_tree['local_translation']['arr'])
# Out:
# Key 'skeleton_tree': sub-keys = ['node_names', 'parent_indices', 'local_translation']
#   First element of 'skeleton_tree["node_names"]': pelvis
#   First element of 'skeleton_tree["parent_indices"]': [-1  0  1  1  3  4  1  6  7  0  9 10  0 12 13]
#   First element of 'skeleton_tree["local_translation"]': [[ 0.        0.        1.      ]
#  [ 0.        0.        0.336151]
#  [ 0.        0.        0.223894]
#  [-0.02405  -0.20311   0.1935  ]
#  [ 0.        0.       -0.274788]
#  [ 0.        0.       -0.258947]
#  [-0.02405   0.20311   0.1935  ]
#  [ 0.        0.       -0.274788]
#  [ 0.        0.       -0.258947]
#  [ 0.       -0.084887  0.      ]
#  [ 0.        0.       -0.451546]
#  [ 0.        0.       -0.43987 ]
#  [ 0.        0.084887  0.      ]
#  [ 0.        0.       -0.451546]
#  [ 0.        0.       -0.43987 ]]

# %%
# 'is_local': not a dict (type=bool)
print("Key 'is_local':", payload['is_local'], f"(type={type(payload['is_local']).__name__})")

# 'fps': not a dict (type=float)
print("Key 'fps':", payload['fps'], f"(type={type(payload['fps']).__name__})")

# '__name__': not a dict (type=str)
print("Key '__name__':", payload['__name__'], f"(type={type(payload['__name__']).__name__})")
# Out:
# Key 'is_local': True (type=bool)
# Key 'fps': 29.968825770696224 (type=float)
# Key '__name__': SkeletonMotion (type=str)

# %%
# 1) Inventory table
inventory_rows = []
for p in npy_files:
    size = p.stat().st_size
    inventory_rows.append({
        "file": str(p),
        "size_bytes": size,
        "size_mb": round(size / (1024 * 1024), 4),
    })

inventory_df = pd.DataFrame(inventory_rows).sort_values("file").reset_index(drop=True)
inventory_df.to_csv(OUT_DIR / "npy_inventory.csv", index=False)
inventory_df.head(10)
# Out:
#                                                 file  size_bytes  size_mb
# 0               motions/pingpong/ROM_blender_pph.npy      823576   0.7854
# 1  motions/pingpong/Transition_looping_FB_blender...     1179148   1.1245
# 2          motions/pingpong/backhand_blender_pph.npy     1789924   1.7070
# 3  motions/pingpong/backhand_block_01_blender_pph...      968008   0.9232
# 4  motions/pingpong/backhand_chop001_blender_pph.npy      894568   0.8531
# 5     motions/pingpong/backhand_chop_blender_pph.npy      961888   0.9173
# 6   motions/pingpong/backhand_lob_02_blender_pph.npy      469840   0.4481
# 7  motions/pingpong/backhand_loop_01_blender_pph.npy      587956   0.5607
# 8  motions/pingpong/backhand_loop_02_blender_pph.npy      786244   0.7498
# 9  motions/pingpong/backhand_push_01_blender_pph.npy     1106320   1.0551

# %%
# 2) Stats table
stats_rows = []
for p in npy_files:
    payload = load_payload(p)
    rot, root_t, gvel, gavel, fps = extract_arrays(payload)

    s = summarize_numeric(rot)
    stats_rows.append({
        "file": str(p),
        "fps": fps,
        "frames": int(rot.shape[0]),
        "joints": int(rot.shape[1]),
        "duration_sec": round(rot.shape[0] / fps, 3),
        "rotation_shape": tuple(rot.shape),
        "root_translation_shape": tuple(root_t.shape),
        "global_velocity_shape": tuple(gvel.shape),
        "global_angular_velocity_shape": tuple(gavel.shape),
        **s,
    })

stats_df = pd.DataFrame(stats_rows).sort_values("file").reset_index(drop=True)
stats_df.to_csv(OUT_DIR / "npy_stats.csv", index=False)
stats_df.head(10)
# Out:
#                                                 file        fps  frames  \
# 0               motions/pingpong/ROM_blender_pph.npy  29.994417    1343
# 1  motions/pingpong/Transition_looping_FB_blender...  29.988304    1924
# 2          motions/pingpong/backhand_blender_pph.npy  30.000000    2922
# 3  motions/pingpong/backhand_block_01_blender_pph...  30.000000    1579
# 4  motions/pingpong/backhand_chop001_blender_pph.npy  29.984576    1459
# 5     motions/pingpong/backhand_chop_blender_pph.npy  30.000000    1569
# 6   motions/pingpong/backhand_lob_02_blender_pph.npy  29.970579     765
# 7  motions/pingpong/backhand_loop_01_blender_pph.npy  29.976507     958
# 8  motions/pingpong/backhand_loop_02_blender_pph.npy  29.988295    1282
# 9  motions/pingpong/backhand_push_01_blender_pph.npy  29.995843    1805
#
#    joints  duration_sec rotation_shape root_translation_shape  \
# 0      15        44.775  (1343, 15, 4)              (1343, 3)
# 1      15        64.158  (1924, 15, 4)              (1924, 3)
# 2      15        97.400  (2922, 15, 4)              (2922, 3)
# 3      15        52.633  (1579, 15, 4)              (1579, 3)
# 4      15        48.658  (1459, 15, 4)              (1459, 3)
# 5      15        52.300  (1569, 15, 4)              (1569, 3)
# 6      15        25.525   (765, 15, 4)               (765, 3)
# 7      15        31.958   (958, 15, 4)               (958, 3)
# 8      15        42.750  (1282, 15, 4)              (1282, 3)
# 9      15        60.175  (1805, 15, 4)              (1805, 3)
#
#   global_velocity_shape global_angular_velocity_shape       min  max  \
# 0         (1343, 15, 3)                 (1343, 15, 3) -0.999749  1.0
# 1         (1924, 15, 3)                 (1924, 15, 3) -0.944542  1.0
# 2         (2922, 15, 3)                 (2922, 15, 3) -0.817840  1.0
# 3         (1579, 15, 3)                 (1579, 15, 3) -0.984221  1.0
# 4         (1459, 15, 3)                 (1459, 15, 3) -0.843855  1.0
# 5         (1569, 15, 3)                 (1569, 15, 3) -0.850517  1.0
# 6          (765, 15, 3)                  (765, 15, 3) -0.790632  1.0
# 7          (958, 15, 3)                  (958, 15, 3) -0.999661  1.0
# 8         (1282, 15, 3)                 (1282, 15, 3) -0.959371  1.0
# 9         (1805, 15, 3)                 (1805, 15, 3) -0.871943  1.0
#
#        mean       std  nan_count  inf_count
# 0  0.226150  0.445933          0          0
# 1  0.209587  0.453953          0          0
# 2  0.221633  0.448195          0          0
# 3  0.215110  0.451362          0          0
# 4  0.227255  0.445371          0          0
# 5  0.223434  0.447300          0          0
# 6  0.230241  0.443835          0          0
# 7  0.213873  0.451949          0          0
# 8  0.214909  0.451458          0          0
# 9  0.225348  0.446339          0          0

# %%
# 3) Frame-0 quaternion table for every file (one concrete frame)
frame0_rows = []
for p in npy_files:
    payload = load_payload(p)
    rot, _, _, _, _ = extract_arrays(payload)
    if rot.shape[0] == 0:
        continue
    frame0 = rot[0]  # [J, 4]
    for j in range(frame0.shape[0]):
        qx, qy, qz, qw = frame0[j]
        frame0_rows.append({
            "file": str(p),
            "frame": 0,
            "joint_index": j,
            "quat_x": float(qx),
            "quat_y": float(qy),
            "quat_z": float(qz),
            "quat_w": float(qw),
        })

frame0_df = pd.DataFrame(frame0_rows)
frame0_df.to_csv(OUT_DIR / "npy_frame0_rotation.csv", index=False)
frame0_df.head(30)
# Out:
#                                                  file  frame  joint_index  \
# 0                motions/pingpong/ROM_blender_pph.npy      0            0
# 1                motions/pingpong/ROM_blender_pph.npy      0            1
# 2                motions/pingpong/ROM_blender_pph.npy      0            2
# 3                motions/pingpong/ROM_blender_pph.npy      0            3
# 4                motions/pingpong/ROM_blender_pph.npy      0            4
# 5                motions/pingpong/ROM_blender_pph.npy      0            5
# 6                motions/pingpong/ROM_blender_pph.npy      0            6
# 7                motions/pingpong/ROM_blender_pph.npy      0            7
# 8                motions/pingpong/ROM_blender_pph.npy      0            8
# 9                motions/pingpong/ROM_blender_pph.npy      0            9
# 10               motions/pingpong/ROM_blender_pph.npy      0           10
# 11               motions/pingpong/ROM_blender_pph.npy      0           11
# 12               motions/pingpong/ROM_blender_pph.npy      0           12
# 13               motions/pingpong/ROM_blender_pph.npy      0           13
# 14               motions/pingpong/ROM_blender_pph.npy      0           14
# 15  motions/pingpong/Transition_looping_FB_blender...      0            0
# 16  motions/pingpong/Transition_looping_FB_blender...      0            1
# 17  motions/pingpong/Transition_looping_FB_blender...      0            2
# 18  motions/pingpong/Transition_looping_FB_blender...      0            3
# 19  motions/pingpong/Transition_looping_FB_blender...      0            4
# 20  motions/pingpong/Transition_looping_FB_blender...      0            5
# 21  motions/pingpong/Transition_looping_FB_blender...      0            6
# 22  motions/pingpong/Transition_looping_FB_blender...      0            7
# 23  motions/pingpong/Transition_looping_FB_blender...      0            8
# 24  motions/pingpong/Transition_looping_FB_blender...      0            9
# 25  motions/pingpong/Transition_looping_FB_blender...      0           10
# 26  motions/pingpong/Transition_looping_FB_blender...      0           11
# 27  motions/pingpong/Transition_looping_FB_blender...      0           12
# 28  motions/pingpong/Transition_looping_FB_blender...      0           13
# 29  motions/pingpong/Transition_looping_FB_blender...      0           14
#
#       quat_x    quat_y    quat_z    quat_w
# 0   0.033760  0.021397  0.997114  0.064548
# 1  -0.041450  0.064138 -0.004420  0.997070
# 2   0.040877  0.012811 -0.310434  0.949629
# 3  -0.157094 -0.069095  0.240876  0.955262
# 4  -0.000000 -0.110061 -0.000000  0.993925
# 5   0.000000  0.000000  0.000000  1.000000
# 6   0.168888  0.002364 -0.270356  0.947828
# 7  -0.000000 -0.218168 -0.000000  0.975911
# 8  -0.001059 -0.018966  0.038852  0.999064
# 9  -0.155012 -0.040333 -0.216183  0.963125
# 10  0.000000  0.076746  0.000000  0.997051
# 11  0.106431  0.007545  0.045585  0.993246
# 12  0.074678  0.019132  0.223966  0.971543
# 13  0.000000  0.060240  0.000000  0.998184
# 14 -0.068146 -0.026110  0.022864  0.997072
# 15  0.013828 -0.027528  0.218391  0.975375
# 16  0.109417  0.129423  0.028438  0.985124
# 17 -0.118915  0.025177  0.438151  0.890645
# 18 -0.260677  0.017940  0.147813  0.953875
# 19 -0.000000 -0.150740 -0.000000  0.988574
# 20  0.000000  0.000000  0.000000  1.000000
# 21  0.151651 -0.027054 -0.194293  0.968773
# 22 -0.000000 -0.685011 -0.000000  0.728533
# 23  0.017069  0.120696 -0.044605  0.991540
# 24 -0.102061 -0.034006 -0.305929  0.945957
# 25  0.000000  0.116786  0.000000  0.993157
# 26  0.061734 -0.033256 -0.034780  0.996932
# 27  0.130915 -0.176682  0.111421  0.969139
# 28  0.000000  0.341715  0.000000  0.939804
# 29 -0.087868  0.037001 -0.002921  0.995440

# %%
# 4) Inspect a few arbitrary frames from one file
file_index = 0
frames_to_show = [0, 1, 2]

path = npy_files[file_index]
payload = load_payload(path)
rot, root_t, _, _, fps = extract_arrays(payload)

print("file:", path)
print("fps:", fps)
print("rotation shape:", rot.shape)
print("root_translation shape:", root_t.shape)

rows = []
for f in frames_to_show:
    if 0 <= f < rot.shape[0]:
        for j in range(rot.shape[1]):
            q = rot[f, j]
            rows.append({
                "frame": f,
                "joint_index": j,
                "quat_x": float(q[0]),
                "quat_y": float(q[1]),
                "quat_z": float(q[2]),
                "quat_w": float(q[3]),
            })

preview_quat_df = pd.DataFrame(rows)
preview_quat_df.head(45)
# Out:
# file: motions/pingpong/ROM_blender_pph.npy
# fps: 29.994416527079846
# rotation shape: (1343, 15, 4)
# root_translation shape: (1343, 3)
#     frame  joint_index    quat_x    quat_y    quat_z    quat_w
# 0       0            0  0.033760  0.021397  0.997114  0.064548
# 1       0            1 -0.041450  0.064138 -0.004420  0.997070
# 2       0            2  0.040877  0.012811 -0.310434  0.949629
# 3       0            3 -0.157094 -0.069095  0.240876  0.955262
# 4       0            4 -0.000000 -0.110061 -0.000000  0.993925
# 5       0            5  0.000000  0.000000  0.000000  1.000000
# 6       0            6  0.168888  0.002364 -0.270356  0.947828
# 7       0            7 -0.000000 -0.218168 -0.000000  0.975911
# 8       0            8 -0.001059 -0.018966  0.038852  0.999064
# 9       0            9 -0.155012 -0.040333 -0.216183  0.963125
# 10      0           10  0.000000  0.076746  0.000000  0.997051
# 11      0           11  0.106431  0.007545  0.045585  0.993246
# 12      0           12  0.074678  0.019132  0.223966  0.971543
# 13      0           13  0.000000  0.060240  0.000000  0.998184
# 14      0           14 -0.068146 -0.026110  0.022864  0.997072
# 15      1            0  0.034370  0.021900  0.997155  0.063413
# 16      1            1 -0.041306  0.064201 -0.004101  0.997073
# 17      1            2  0.040086  0.012011 -0.307149  0.950741
# 18      1            3 -0.157770 -0.068317  0.239653  0.955515
# 19      1            4 -0.000000 -0.108979 -0.000000  0.994044
# 20      1            5  0.000000  0.000000  0.000000  1.000000
# 21      1            6  0.169444  0.002688 -0.269261  0.948040
# 22      1            7 -0.000000 -0.218642 -0.000000  0.975805
# 23      1            8 -0.000980 -0.019418  0.037738  0.999099
# 24      1            9 -0.155723 -0.039249 -0.217474  0.962764
# 25      1           10  0.000000  0.075942  0.000000  0.997112
# 26      1           11  0.106663  0.008120  0.046494  0.993174
# 27      1           12  0.073947  0.021412  0.226142  0.971047
# 28      1           13  0.000000  0.056534  0.000000  0.998401
# 29      1           14 -0.068087 -0.024475  0.020493  0.997169
# 30      2            0  0.035202  0.022651  0.997180  0.062291
# 31      2            1 -0.041110  0.064417 -0.003894  0.997068
# 32      2            2  0.038614  0.010677 -0.302444  0.952325
# 33      2            3 -0.158528 -0.067042  0.237949  0.955905
# 34      2            4 -0.000000 -0.107439 -0.000000  0.994212
# 35      2            5  0.000000  0.000000  0.000000  1.000000
# 36      2            6  0.168549  0.002846 -0.268074  0.948536
# 37      2            7 -0.000000 -0.218990 -0.000000  0.975727
# 38      2            8 -0.001059 -0.019908  0.036664  0.999129
# 39      2            9 -0.156931 -0.038052 -0.220086  0.962022
# 40      2           10  0.000000  0.074433  0.000000  0.997226
# 41      2           11  0.106981  0.008615  0.048095  0.993060
# 42      2           12  0.072769  0.024904  0.229459  0.970275
# 43      2           13  0.000000  0.050519  0.000000  0.998723
# 44      2           14 -0.068179 -0.021754  0.016231  0.997304

# %%
# 5) Root translation for same selected frames
root_rows = []
for f in frames_to_show:
    if 0 <= f < root_t.shape[0]:
        x, y, z = root_t[f]
        root_rows.append({
            "frame": f,
            "root_x": float(x),
            "root_y": float(y),
            "root_z": float(z),
        })

root_preview_df = pd.DataFrame(root_rows)
root_preview_df
# Out:
#    frame    root_x    root_y    root_z
# 0      0  0.094144 -0.025542  0.887501
# 1      1  0.094200 -0.025690  0.887506
# 2      2  0.094255 -0.025956  0.887512
